# %% [markdown]
# ## Data Cleanup
#
# ### Imports & EC3 Python Wrapper Setup

# %%
import os
import pandas as pd
import json

# %% [markdown]
# ### Define Cleaning Functions

# %%
def remove_outliers(df, col_names):
    """
    Remove extreme outliers based on IQR method across the full dataset.
    """
    q1 = df[col_names].quantile(0.25)
    q3 = df[col_names].quantile(0.75)
    iqr = q3 - q1

    df = df[~((df[col_names] < (q1 - 1.5 * iqr)) | (df[col_names] > (q3 + 1.5 * iqr))).any(axis=1)]

    return df.copy()


def remove_outliers_per_bucket(df, gwp_col, bucket_col):
    """
    Remove outliers within each compressive strength bucket using IQR method.
    More precise than global IQR since each strength class has a different GWP distribution.
    """
    def iqr_filter(group):
        q1 = group[gwp_col].quantile(0.25)
        q3 = group[gwp_col].quantile(0.75)
        iqr = q3 - q1
        lower = q1 - 1.5 * iqr
        upper = q3 + 1.5 * iqr
        return group[(group[gwp_col] >= lower) & (group[gwp_col] <= upper)]

    return df.groupby(bucket_col, group_keys=False).apply(iqr_filter).reset_index(drop=True)

# %% [markdown]
# ### Load JSON

# %%
# Navigate into the 01_raw_data folder to load the data
os.chdir(os.path.dirname(os.getcwd()))
os.chdir('01_raw_data')

#NOTE Change file to load accordingly. This is intended to take the raw data files generated from the ec3_concrete_epd_gather_[name].ipynb notebooks
with open('epd_data_all.json', 'r') as f:
    epd_data_all = json.load(f)

# %% [markdown]
# ### Cleaning the Data

# %%
# Flatten the nested JSON using pandas json_normalize
# This automatically handles nested dictionaries with dot notation
df = pd.json_normalize(epd_data_all)

# %%
df.dropna(subset=['plant_or_group.latitude', 'plant_or_group.longitude'], inplace=True)
df = df.dropna(subset=['concrete_compressive_strength_28d', 'concrete_compressive_strength_other'], how='all')

# %%
#add a column for the gwp formatted as a float converted to kgCO2e per cubic yard
df['gwp_val_per_cy'] = (
    df['gwp_per_category_declared_unit']
    .str.extract(r'(\d+\.?\d*)')
    .astype(float)
    .round(1) * 0.764555
)

# %%
# remove epd if gwp value is an outlier
df = remove_outliers(df, ['gwp_val_per_cy'])

#add a column for the date formatted as a datetime object
df['created_date_formatted'] = pd.to_datetime(df['created_on'], format='ISO8601')

df = df[df['created_date_formatted'].dt.year >= 2020] #only keep EPDs from 2020 and later

len(df) #check length of dataset after cleaning steps
# Out:
# 75140

# %%
# Convert compressive strength to psi and round to nearest 500
def convert_strength_to_psi(strength_str):
    if pd.isna(strength_str):
        return None
    split_strength = strength_str.split()
    if split_strength[1] == "MPa":
        conc_strength = float(split_strength[0]) * 145.03773773
    elif split_strength[1] == "psi":
        conc_strength = float(split_strength[0])
    elif split_strength[1] == "ksi":
        conc_strength = float(split_strength[0]) * 1000
    else:
        return None

    return int(round(conc_strength / 500.0) * 500.0)

# Pick the larger of the two strength values when both exist, otherwise use whichever is present
def pick_compressive_strength(row):
    val_28d = convert_strength_to_psi(row['concrete_compressive_strength_28d'])
    val_other = convert_strength_to_psi(row['concrete_compressive_strength_other'])
    if val_28d is not None and val_other is not None:
        return max(val_28d, val_other)
    return val_28d if val_28d is not None else val_other

# Apply conversion to dataframe
df['Compressive_Strength'] = df.apply(pick_compressive_strength, axis=1)

# Drop rows where conversion failed (unknown units)
df = df.dropna(subset=['Compressive_Strength'])

# Convert Compressive_Strength to int
df['Compressive_Strength'] = df['Compressive_Strength'].astype(int)

# %%
# Remove outliers within each compressive strength bucket
before = len(df)
df = remove_outliers_per_bucket(df, 'gwp_val_per_cy', 'Compressive_Strength')
print(f"Per-bucket IQR: removed {before - len(df)} rows ({len(df)} remaining)")
# Out:
# Per-bucket IQR: removed 396 rows (74722 remaining)
# C:\Users\jaredf\AppData\Local\Temp\ipykernel_266876\2549748023.py:27: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(bucket_col, group_keys=False).apply(iqr_filter).reset_index(drop=True)

# %% [markdown]
# ### Save data out (as pickle)

# %%
#NOTE Change file name accordingly
df.to_pickle('../02_processed_data/epd_data_cleaned_all.pkl')
