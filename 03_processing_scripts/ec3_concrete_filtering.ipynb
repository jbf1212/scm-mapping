# %% [markdown]
# ## Filter Down EC3 data for Further Studies

# %% [markdown]
# ### Filter out only mixes with flyash as SCM

# %%
import pandas as pd

# Load in cleaned data
df = pd.read_pickle('../02_processed_data/epd_data_cleaned.pkl')
df.head()
# Out:
#           gwp  lightweight                                id  \
# 0  319 kgCO2e        False  a213fdb0dbeb449ebb9595c6eba75af4
# 1  318 kgCO2e        False  c773e40a243741a4a13c43af17a42fa9
# 2  318 kgCO2e        False  0f36072df02344ca8eb9f215a8954a69
# 3  291 kgCO2e        False  3a6aa86f423a469f981115b68838be3c
# 4  289 kgCO2e        False  abb548d9550a450492870f5084dd4325
#
#   gwp_per_category_declared_unit concrete_compressive_strength_28d  \
# 0                     319 kgCO2e                          55.2 MPa
# 1                     318 kgCO2e                            31 MPa
# 2                     318 kgCO2e                          34.5 MPa
# 3                     291 kgCO2e                          37.9 MPa
# 4                     289 kgCO2e                          34.5 MPa
#
#               name                   updated_on open_xpd_uuid  \
# 0  Mix SRM80S5BSNA  2024-05-24T15:40:10.256074Z      ec3wdhqk
# 1       Mix 390863  2024-05-24T16:03:40.536347Z      ec3kkxe7
# 2       Mix 390866  2024-05-24T15:17:11.241268Z      ec36963f
# 3      Mix 506-S45  2024-05-24T15:31:40.346516Z      ec3ndbwz
# 4    Mix 50IM40%SL  2024-05-24T15:00:31.466560Z      ec3ptdhb
#
#                     created_on  uncertainty_factor  ...  \
# 0  2024-04-26T21:02:50.898997Z            1.094574  ...
# 1  2024-04-26T20:25:15.276652Z            1.094574  ...
# 2  2024-04-26T20:23:56.162527Z            1.094574  ...
# 3  2024-04-26T20:12:49.431963Z            1.094574  ...
# 4  2024-04-26T20:02:37.949597Z            1.094574  ...
#
#                        plant_or_group.name    plant_or_group.updated_on  \
# 0                         Long Island City  2024-08-29T15:11:43.148443Z
# 1                                   Hilroy  2024-07-19T16:00:02.097740Z
# 2                                   Hilroy  2024-07-19T16:00:02.097740Z
# 3  Prestress – Spokane Valley (Washington)  2024-08-23T18:52:22.419903Z
# 4                                    Bronx  2024-07-23T07:58:43.043312Z
#
#      plant_or_group.created_on  plant_or_group.type cementitious.ggbs  \
# 0  2023-05-03T08:37:37.808959Z                Plant              0.50
# 1  2024-02-20T22:54:03.331812Z                Plant              0.40
# 2  2024-02-20T22:54:03.331812Z                Plant              0.50
# 3  2023-10-18T11:47:14.114325Z                Plant              0.45
# 4  2023-05-04T20:27:47.059512Z                Plant              0.40
#
#   concrete_aggregate_size_max cementitious.fly_ash gwp_val_per_cy  \
# 0                         NaN                  NaN     243.893045
# 1                     0.75 in                  NaN     243.128490
# 2                     0.75 in                  NaN     243.128490
# 3                         NaN                  NaN     222.485505
# 4                     0.75 in                  NaN     220.956395
#
#             created_date_formatted Compressive_Strength
# 0 2024-04-26 21:02:50.898997+00:00                 8000
# 1 2024-04-26 20:25:15.276652+00:00                 4500
# 2 2024-04-26 20:23:56.162527+00:00                 5000
# 3 2024-04-26 20:12:49.431963+00:00                 5500
# 4 2024-04-26 20:02:37.949597+00:00                 5000
#
# [5 rows x 24 columns]

# %%
#filter for mixes where there is a value for cementitious.fly_ash
df_fly_ash = df[df['cementitious.fly_ash'].notna()]

# %%
# Save the filtered dataframe to a csv in my processed data folder
df_fly_ash.to_csv('../02_processed_data/epd_data_fly_ash.csv', index=False)
